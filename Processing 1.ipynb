# %% [markdown]
# ### Parse Transcripts

# %%
import re
import os

def parse_transcript_md(file_path):
    speaker_pattern = re.compile(r'\*\*(.+?):\*\*')  
    segments = []
    
    with open(file_path, "r", encoding="utf-8") as f:
        lines = f.readlines()
    
    current_speaker = None
    current_text = []
    
    for line in lines:
        speaker_match = speaker_pattern.match(line.strip())
        if speaker_match:
          
            if current_speaker is not None and current_text:
                segments.append({
                    "speaker": current_speaker.strip(),
                    "text": " ".join(current_text).strip()
                })
            current_speaker = speaker_match.group(1)
            current_text = [line[speaker_match.end():].strip()]
        else:
            if line.strip():
                current_text.append(line.strip())
    

    if current_speaker and current_text:
        segments.append({
            "speaker": current_speaker.strip(),
            "text": " ".join(current_text).strip()
        })
    
    return segments

def parse_all_transcripts(transcripts_folder):
    all_parsed = {}
    for filename in os.listdir(transcripts_folder):
        if filename.endswith(".md"):
            file_path = os.path.join(transcripts_folder, filename)
            segments = parse_transcript_md(file_path)
            all_parsed[filename] = segments
    return all_parsed


transcripts_folder_path = "/Users/kiran/Desktop/TDM/Sample Train Set /Transcripts" 
all_transcripts_parsed = parse_all_transcripts(transcripts_folder_path)

for fname, segments in all_transcripts_parsed.items():
    print(f"\nFile: {fname} - Total segments extracted: {len(segments)}")
    for seg in segments[:3]:  # Show first 3 segments per file
        print(f"Speaker: {seg['speaker']}\nText: {seg['text']}\n")
# Out:
# File: episode_295.md - Total segments extracted: 46
# Speaker: Daniel Whitenack
# Text: In this Fully Connected episode of the show Chris and I will keep you fully connected with everything that's happening in the world of AI, and discuss some of the latest trends and share some learning resources for you to level up your machine learning and AI game. I'm Daniel Whitenack. I am CEO at PredictionGuard, where we're creating a private, secure AI platform. And I'm joined as always by my co-host, Chris Benson, who is a principal AI research engineer at Lockheed Martin. How are you doing, Chris?
#
# Speaker: Chris Benson
# Text: Doing very well, Daniel. I know you're out traveling, and ironically, I think I'll be where you are next week, but I think you'll be gone by then.
#
# Speaker: Daniel Whitenack
# Text: Swapping places.
#
#
# File: episode_282.md - Total segments extracted: 43
# Speaker: Daniel Whitenack
# Text: Welcome to another Fully Connected episode of the Practical AI Podcast. This is Daniel Whitenack. I am the founder and CEO of Prediction Guard, and I'm joined as always by my co-host, Chris Benson, who is a principal AI research engineer at Lockheed Martin. In these Fully Connected episodes Chris and I will keep you fully connected with some of the things happening in the AI news and trends, and we'll also discuss a few topics that will help you level up your machine learning game. How are you doing, Chris?
#
# Speaker: Chris Benson
# Text: Doing good. How are you today, Daniel? I think you're traveling, aren't you?
#
# Speaker: Daniel Whitenack
# Text: I am in transit, so hopefully the hotel Wi-Fi/hotspot holds out and we can keep it going. But yeah, going over to GopherCon UK, which should be fun to talk to a few Go programmers about AI, and integrating it into Go applications. So that should be fun.
#
#
# File: episode_287.md - Total segments extracted: 47
# Speaker: Daniel Whitenack
# Text: Welcome to another Fully Connected episode of the Practical AI podcast. This is Daniel Whitenack. I am the CEO and founder at Prediction Guard, and I'm joined by my co-host, Chris Benson, who is a principal AI research engineer at Lockheed Martin. In these Fully Connected episodes we try to keep you fully connected with everything that's happening in the machine learning and data science and AI worlds, and hopefully share some things with you that will help you level up your machine learning and AI game. How are you doing, Chris? It'll be fun to catch up on a few things that have been happening over the past couple weeks today.
#
# Speaker: Chris Benson
# Text: There's so much going on, oh my gosh.
#
# Speaker: Daniel Whitenack
# Text: Always, yes.
#
#
# File: episode_297.md - Total segments extracted: 73
# Speaker: Daniel Whitenack
# Text: Welcome to another Fully Connected episode of the Practical AI podcast. In these episodes Chris and I try to keep you fully connected with everything that's happening in the AI space, and hopefully share some things that will help you level up your machine learning game. I'm Daniel Whitenack, I'm CEO at Prediction Guard, where we're deploying a platform for private and secure AI, and I'm joined as always by my co-host, Chris Benson, who is a principal AI research engineer at Lockheed Martin. How are you doing, Chris?
#
# Speaker: Chris Benson
# Text: Doing very well, Daniel. I'm podcasting from outside today...
#
# Speaker: Daniel Whitenack
# Text: That's exciting.

# %% [markdown]
# ### Generate transcripts with segment and word level timestamps

# %%
import os
import whisper

def transcribe_all_audio_with_timestamps(audio_folder):
    """
    Transcribe all mp3 audio files in a folder using Whisper with word-level timestamps.
    
    Args:
        audio_folder (str): Path to folder containing audio files
        
    Returns:
        dict: Mapping of filename -> transcription result with timestamps
    """

    model = whisper.load_model("small", device="cpu") #Small for now because I traded off accuracy for time
    
    transcription_results = {}
    
    for filename in os.listdir(audio_folder):
        if filename.endswith(".mp3"):
            audio_path = os.path.join(audio_folder, filename)
            print(f"Transcribing {filename} ...")
            result = model.transcribe(audio_path, word_timestamps=True)
            transcription_results[filename] = result
            print(f"Done with {filename}. Segments: {len(result['segments'])}")
    
    return transcription_results


audio_folder_path = "/Users/kiran/Desktop/TDM/Sample Train Set /Audio"
all_transcriptions = transcribe_all_audio_with_timestamps(audio_folder_path)


first_file = next(iter(all_transcriptions))
for segment in all_transcriptions[first_file]["segments"]:
    print(f"Segment [{segment['start']:.2f} - {segment['end']:.2f}]: {segment['text']}")
    for word in segment.get("words", []):
        print(f"  Word: {word['word']} [{word['start']:.2f} - {word['end']:.2f}]")
# Out:
# Transcribing episode_287.mp3 ...
# /opt/anaconda3/envs/tts_env/lib/python3.11/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Done with episode_287.mp3. Segments: 458
# Transcribing episode_295.mp3 ...
# /opt/anaconda3/envs/tts_env/lib/python3.11/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Done with episode_295.mp3. Segments: 407
# Transcribing episode_297.mp3 ...
# /opt/anaconda3/envs/tts_env/lib/python3.11/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Done with episode_297.mp3. Segments: 565
# Transcribing episode_282.mp3 ...
# /opt/anaconda3/envs/tts_env/lib/python3.11/site-packages/whisper/transcribe.py:132: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# Done with episode_282.mp3. Segments: 446
# Segment [15.92 - 18.46]:  Welcome to Practical AI.
#   Word:  Welcome [15.92 - 16.76]
#   Word:  to [16.76 - 17.36]
#   Word:  Practical [17.36 - 18.18]
#   Word:  AI. [18.18 - 18.46]
# Segment [19.18 - 26.62]:  If you work in artificial intelligence, aspire to, or are curious how AI-related tech is
#   Word:  If [19.18 - 19.54]
#   Word:  you [19.54 - 19.72]
#   Word:  work [19.72 - 19.94]
#   Word:  in [19.94 - 20.22]
#   Word:  artificial [20.22 - 20.54]
#   Word:  intelligence, [20.54 - 21.30]
#   Word:  aspire [21.76 - 22.18]
#   Word:  to, [22.18 - 22.54]
#   Word:  or [23.12 - 23.36]
#   Word:  are [23.36 - 23.60]
#   Word:  curious [23.60 - 24.14]
#   Word:  how [24.14 - 24.96]
#   Word:  AI [24.96 - 25.40]
#   Word: -related [25.40 - 25.86]
#   Word:  tech [25.86 - 26.24]
#   Word:  is [26.24 - 26.62]
# Segment [26.62 - 32.54]:  changing the world, this is the show for you. Thank you to our partners at fly.io,
#   Word:  changing [26.62 - 26.96]
#   Word:  the [26.96 - 27.12]
#   Word:  world, [27.12 - 27.52]
#   Word:  this [27.84 - 28.22]
#   Word:  is [28.22 - 28.50]
#   Word:  the [28.50 - 28.66]
#   Word:  show [28.66 - 28.88]
#   Word:  for [28.88 - 29.10]
#   Word:  you. [29.10 - 29.36]
#   Word:  Thank [30.04 - 30.36]
#   Word:  you [30.36 - 30.52]
#   Word:  to [30.52 - 30.66]
#   Word:  our [30.66 - 30.84]
#   Word:  partners [30.84 - 31.22]
#   Word:  at [31.22 - 31.56]
#   Word:  fly [31.56 - 31.92]
#   Word: .io, [31.92 - 32.54]
# Segment [33.00 - 37.26]:  the home of changelog.com. Learn more at fly.io.
#   Word:  the [33.00 - 33.16]
#   Word:  home [33.16 - 33.46]
#   Word:  of [33.46 - 33.68]
#   Word:  changelog [33.68 - 34.16]
#   Word: .com. [34.16 - 34.68]
#   Word:  Learn [35.24 - 35.36]
#   Word:  more [35.36 - 35.66]
#   Word:  at [35.66 - 36.12]
#   Word:  fly [36.12 - 36.50]
#   Word: .io. [36.50 - 37.26]
# Segment [50.72 - 55.16]:  What's up friends? I'm here with a new friend of ours over at Assembly AI.
#   Word:  What's [50.72 - 51.36]
#   Word:  up [51.36 - 51.42]
#   Word:  friends? [51.42 - 51.68]
#   Word:  I'm [52.00 - 52.16]
#   Word:  here [52.16 - 52.24]
#   Word:  with [52.24 - 52.36]
#   Word:  a [52.36 - 52.44]
#   Word:  new [52.44 - 52.52]
#   Word:  friend [52.52 - 52.70]
#   Word:  of [52.70 - 52.82]
#   Word:  ours [52.82 - 53.10]
#   Word:  over [53.10 - 53.60]
#   Word:  at [53.60 - 53.98]
#   Word:  Assembly [53.98 - 54.56]
#   Word:  AI. [54.56 - 55.16]
# Segment [55.72 - 61.20]:  Founder and CEO, Dylan Fox. Assembly AI is where you can turn voice data into insights,
#   Word:  Founder [55.72 - 56.30]
#   Word:  and [56.30 - 56.56]
#   Word:  CEO, [56.56 - 56.90]
#   Word:  Dylan [57.16 - 57.30]
#   Word:  Fox. [57.30 - 57.60]
#   Word:  Assembly [58.24 - 58.56]
#   Word:  AI [58.56 - 58.86]
#   Word:  is [58.86 - 59.14]
#   Word:  where [59.14 - 59.24]
#   Word:  you [59.24 - 59.32]
#   Word:  can [59.32 - 59.42]
#   Word:  turn [59.42 - 59.58]
#   Word:  voice [59.58 - 59.90]
#   Word:  data [59.90 - 60.22]
#   Word:  into [60.22 - 60.58]
#   Word:  insights, [60.58 - 61.20]
# Segment [61.70 - 68.06]:  chapters, transcripts, summaries, and so much more with their leading speech AI models.
#   Word:  chapters, [61.70 - 62.12]
#   Word:  transcripts, [62.84 - 63.82]
#   Word:  summaries, [63.92 - 64.52]
#   Word:  and [64.78 - 65.08]
#   Word:  so [65.08 - 65.28]
#   Word:  much [65.28 - 65.44]
#   Word:  more [65.44 - 65.68]
#   Word:  with [65.68 - 65.86]
#   Word:  their [65.86 - 65.98]
#   Word:  leading [65.98 - 66.34]
#   Word:  speech [66.34 - 66.90]
#   Word:  AI [66.90 - 67.44]
#   Word:  models. [67.44 - 68.06]
# Segment [68.80 - 72.72]:  So Dylan, give me a glimpse into what you're doing with speech AI models at Assembly AI.
#   Word:  So [68.80 - 68.82]
#   Word:  Dylan, [68.82 - 69.02]
#   Word:  give [69.10 - 69.18]
#   Word:  me [69.18 - 69.28]
#   Word:  a [69.28 - 69.40]
#   Word:  glimpse [69.40 - 69.66]
#   Word:  into [69.66 - 70.02]
#   Word:  what [70.02 - 70.18]
#   Word:  you're [70.18 - 70.30]
#   Word:  doing [70.30 - 70.52]
#   Word:  with [70.52 - 70.66]
#   Word:  speech [70.66 - 70.94]
#   Word:  AI [70.94 - 71.26]
#   Word:  models [71.26 - 71.82]
#   Word:  at [71.82 - 72.20]
#   Word:  Assembly [72.20 - 72.48]
#   Word:  AI. [72.48 - 72.72]
# Segment [73.26 - 79.38]:  So at Assembly, we're building industry leading speech AI models for various tasks like speech
#   Word:  So [73.26 - 73.50]
#   Word:  at [73.50 - 73.94]
#   Word:  Assembly, [73.94 - 74.22]
#   Word:  we're [74.52 - 74.56]
#   Word:  building [74.56 - 74.96]
#   Word:  industry [74.96 - 75.58]
#   Word:  leading [75.58 - 75.88]
#   Word:  speech [75.88 - 76.36]
#   Word:  AI [76.36 - 76.66]
#   Word:  models [76.66 - 77.06]
#   Word:  for [77.06 - 77.42]
#   Word:  various [77.42 - 78.08]
#   Word:  tasks [78.08 - 78.62]
#   Word:  like [78.62 - 79.02]
#   Word:  speech [79.02 - 79.38]
# Segment [79.38 - 84.86]:  to text, streaming speech to text, speech understanding to help developers easily convert
#   Word:  to [79.38 - 79.62]
#   Word:  text, [79.62 - 79.90]
#   Word:  streaming [80.26 - 80.70]
#   Word:  speech [80.70 - 81.04]
#   Word:  to [81.04 - 81.26]
#   Word:  text, [81.26 - 81.54]
#   Word:  speech [81.70 - 81.82]
#   Word:  understanding [81.82 - 82.36]
#   Word:  to [82.36 - 82.86]
#   Word:  help [82.86 - 83.08]
#   Word:  developers [83.08 - 83.56]
#   Word:  easily [83.56 - 84.10]
#   Word:  convert [84.10 - 84.86]
# Segment [84.86 - 89.70]:  voice data, whether it's live or pre-reported, into super accurate text, and then to help
#   Word:  voice [84.86 - 85.34]
#   Word:  data, [85.34 - 85.64]
#   Word:  whether [85.80 - 85.90]
#   Word:  it's [85.90 - 86.10]
#   Word:  live [86.10 - 86.30]
#   Word:  or [86.30 - 86.48]
#   Word:  pre [86.48 - 86.58]
#   Word: -reported, [86.58 - 87.18]
#   Word:  into [87.20 - 87.46]
#   Word:  super [87.46 - 87.86]
#   Word:  accurate [87.86 - 88.20]
#   Word:  text, [88.20 - 88.68]
#   Word:  and [88.94 - 89.20]
#   Word:  then [89.20 - 89.40]
#   Word:  to [89.40 - 89.62]
#   Word:  help [89.62 - 89.70]
# Segment [89.70 - 94.72]:  developers extract a ton of information and metadata around voice data or even around the
#   Word:  developers [89.70 - 90.12]
#   Word:  extract [90.12 - 90.76]
#   Word:  a [90.76 - 91.18]
#   Word:  ton [91.18 - 91.20]
#   Word:  of [91.20 - 91.30]
#   Word:  information [91.30 - 91.62]
#   Word:  and [91.62 - 91.94]
#   Word:  metadata [91.94 - 92.36]
#   Word:  around [92.36 - 92.98]
#   Word:  voice [92.98 - 93.52]
#   Word:  data [93.52 - 93.82]
#   Word:  or [93.82 - 94.04]
#   Word:  even [94.04 - 94.18]
#   Word:  around [94.18 - 94.54]
#   Word:  the [94.54 - 94.72]
# Segment [94.72 - 99.56]:  text that they just were able to convert from that audio data. So these are things like picking out
#   Word:  text [94.72 - 95.00]
#   Word:  that [95.00 - 95.18]
#   Word:  they [95.18 - 95.30]
#   Word:  just [95.30 - 95.62]
#   Word:  were [95.62 - 96.12]
#   Word:  able [96.12 - 96.32]
#   Word:  to [96.32 - 96.46]
#   Word:  convert [96.46 - 96.78]
#   Word:  from [96.78 - 97.02]
#   Word:  that [97.02 - 97.18]
#   Word:  audio [97.18 - 97.42]
#   Word:  data. [97.42 - 97.68]
#   Word:  So [97.82 - 97.88]
#   Word:  these [97.88 - 98.04]
#   Word:  are [98.04 - 98.20]
#   Word:  things [98.20 - 98.46]
#   Word:  like [98.46 - 98.86]
#   Word:  picking [98.86 - 99.36]
#   Word:  out [99.36 - 99.56]
# Segment [99.56 - 108.24]:  entities or PII that was spoken in voice files or summarizing voice and audio data down into
#   Word:  entities [99.56 - 100.08]
#   Word:  or [100.08 - 100.62]
#   Word:  PII [100.62 - 101.10]
#   Word:  that [101.10 - 101.90]
#   Word:  was [101.90 - 102.28]
#   Word:  spoken [102.28 - 102.88]
#   Word:  in [102.88 - 103.22]
#   Word:  voice [103.22 - 103.48]
#   Word:  files [103.48 - 103.88]
#   Word:  or [103.88 - 104.40]
#   Word:  summarizing [104.40 - 105.46]
#   Word:  voice [105.46 - 106.02]
#   Word:  and [106.02 - 106.44]
#   Word:  audio [106.44 - 106.72]
#   Word:  data [106.72 - 107.02]
#   Word:  down [107.02 - 107.70]
#   Word:  into [107.70 - 108.24]
# Segment [108.24 - 113.80]:  custom summaries. It's things like being able to detect how many speakers spoke and who said
#   Word:  custom [108.24 - 108.96]
#   Word:  summaries. [108.96 - 109.50]
#   Word:  It's [109.84 - 110.20]
#   Word:  things [110.20 - 110.44]
#   Word:  like [110.44 - 110.92]
#   Word:  being [110.92 - 111.38]
#   Word:  able [111.38 - 111.56]
#   Word:  to [111.56 - 111.68]
#   Word:  detect [111.68 - 111.94]
#   Word:  how [111.94 - 112.16]
#   Word:  many [112.16 - 112.28]
#   Word:  speakers [112.28 - 112.60]
#   Word:  spoke [112.60 - 113.18]
#   Word:  and [113.18 - 113.48]
#   Word:  who [113.48 - 113.62]
#   Word:  said [113.62 - 113.80]
# Segment [113.80 - 118.70]:  what and what the names of different speakers were. So we bundle all those things into a super
#   Word:  what [113.80 - 114.08]
#   Word:  and [114.08 - 114.26]
#   Word:  what [114.26 - 114.40]
#   Word:  the [114.40 - 114.52]
#   Word:  names [114.52 - 114.78]
#   Word:  of [114.78 - 114.92]
#   Word:  different [114.92 - 115.12]
#   Word:  speakers [115.12 - 115.46]
#   Word:  were. [115.46 - 115.78]
#   Word:  So [116.08 - 116.20]
#   Word:  we [116.20 - 116.34]
#   Word:  bundle [116.34 - 116.60]
#   Word:  all [116.60 - 116.96]
#   Word:  those [116.96 - 117.22]
#   Word:  things [117.22 - 117.62]
#   Word:  into [117.62 - 118.30]
#   Word:  a [118.30 - 118.48]
#   Word:  super [118.48 - 118.70]
# Segment [118.70 - 124.92]:  simple API with really great docs that developers can just sign up to for free to start, use the
#   Word:  simple [118.70 - 118.96]
#   Word:  API [118.96 - 119.28]
#   Word:  with [119.28 - 119.94]
#   Word:  really [119.94 - 120.22]
#   Word:  great [120.22 - 120.52]
#   Word:  docs [120.52 - 121.06]
#   Word:  that [121.06 - 121.84]
#   Word:  developers [121.84 - 122.28]
#   Word:  can [122.28 - 122.64]
#   Word:  just [122.64 - 122.78]
#   Word:  sign [122.78 - 123.00]
#   Word:  up [123.00 - 123.14]
#   Word:  to [123.14 - 123.32]
#   Word:  for [123.32 - 123.52]
#   Word:  free [123.52 - 123.84]
#   Word:  to [123.84 - 124.14]
#   Word:  start, [124.14 - 124.44]
#   Word:  use [124.68 - 124.78]
#   Word:  the [124.78 - 124.92]
# Segment [124.92 - 129.56]:  API, build into their apps, and then build these really cool AI apps and products and
#   Word:  API, [124.92 - 125.24]
#   Word:  build [125.50 - 125.66]
#   Word:  into [125.66 - 125.86]
#   Word:  their [125.86 - 126.02]
#   Word:  apps, [126.02 - 126.32]
#   Word:  and [126.50 - 126.58]
#   Word:  then [126.58 - 126.72]
#   Word:  build [126.72 - 126.98]
#   Word:  these [126.98 - 127.24]
#   Word:  really [127.24 - 127.52]
#   Word:  cool [127.52 - 127.78]
#   Word:  AI [127.78 - 128.12]
#   Word:  apps [128.12 - 128.86]
#   Word:  and [128.86 - 129.04]
#   Word:  products [129.04 - 129.36]
#   Word:  and [129.36 - 129.56]
# Segment [129.56 - 134.70]:  workflows and automations on top of voice data with. I dig it. Okay. Can you take me a little
#   Word:  workflows [129.56 - 129.88]
#   Word:  and [129.88 - 130.14]
#   Word:  automations [130.14 - 130.68]
#   Word:  on [130.68 - 131.02]
#   Word:  top [131.02 - 131.18]
#   Word:  of [131.18 - 131.38]
#   Word:  voice [131.38 - 131.52]
#   Word:  data [131.52 - 131.74]
#   Word:  with. [131.74 - 132.02]
#   Word:  I [132.28 - 132.66]
#   Word:  dig [132.66 - 132.82]
#   Word:  it. [132.82 - 132.98]
#   Word:  Okay. [133.10 - 133.26]
#   Word:  Can [133.42 - 133.68]
#   Word:  you [133.68 - 133.78]
#   Word:  take [133.78 - 133.90]
#   Word:  me [133.90 - 134.12]
#   Word:  a [134.12 - 134.50]
#   Word:  little [134.50 - 134.70]
# Segment [134.70 - 139.38]:  deeper into the opportunity for developers because it seems like there's a lot of voice data out
#   Word:  deeper [134.70 - 135.12]
#   Word:  into [135.12 - 135.46]
#   Word:  the [135.46 - 135.64]
#   Word:  opportunity [135.64 - 136.16]
#   Word:  for [136.16 - 136.34]
#   Word:  developers [136.34 - 136.72]
#   Word:  because [136.72 - 137.12]
#   Word:  it [137.12 - 137.58]
#   Word:  seems [137.58 - 137.88]
#   Word:  like [137.88 - 138.04]
#   Word:  there's [138.04 - 138.22]
#   Word:  a [138.22 - 138.30]
#   Word:  lot [138.30 - 138.42]
#   Word:  of [138.42 - 138.56]
#   Word:  voice [138.56 - 138.88]
#   Word:  data [138.88 - 139.12]
#   Word:  out [139.12 - 139.38]
# Segment [139.38 - 145.68]:  there and there's a lot of trapped value in that voice data. There's so much voice data being created
#   Word:  there [139.38 - 139.62]
#   Word:  and [139.62 - 140.12]
#   Word:  there's [140.12 - 140.44]
#   Word:  a [140.44 - 140.52]
#   Word:  lot [140.52 - 140.62]
#   Word:  of [140.62 - 140.76]
#   Word:  trapped [140.76 - 141.10]
#   Word:  value [141.10 - 141.82]
#   Word:  in [141.82 - 142.32]
#   Word:  that [142.32 - 142.46]
#   Word:  voice [142.46 - 142.66]
#   Word:  data. [142.66 - 142.98]
#   Word:  There's [143.48 - 144.00]
#   Word:  so [144.00 - 144.44]
#   Word:  much [144.44 - 144.64]
#   Word:  voice [144.64 - 144.88]
#   Word:  data [144.88 - 145.12]
#   Word:  being [145.12 - 145.36]
#   Word:  created [145.36 - 145.68]
# Segment [145.68 - 152.82]:  on the internet now, podcasts, videos, phone calls, voice messages, audiobooks, virtual meetings,
#   Word:  on [145.68 - 145.88]
#   Word:  the [145.88 - 145.96]
#   Word:  internet [145.96 - 146.20]
#   Word:  now, [146.20 - 146.50]
#   Word:  podcasts, [146.74 - 147.32]
#   Word:  videos, [147.86 - 148.54]
#   Word:  phone [149.14 - 149.34]
#   Word:  calls, [149.34 - 149.76]
#   Word:  voice [150.06 - 150.26]
#   Word:  messages, [150.26 - 150.78]
#   Word:  audiobooks, [151.40 - 152.24]
#   Word:  virtual [152.30 - 152.56]
#   Word:  meetings, [152.56 - 152.82]
# Segment [153.14 - 158.72]:  crazy. And you can now transform and understand all this voice and audio data in ways that
#   Word:  crazy. [153.14 - 153.36]
#   Word:  And [153.76 - 153.92]
#   Word:  you [153.92 - 154.10]
#   Word:  can [154.10 - 154.28]
#   Word:  now [154.28 - 154.64]
#   Word:  transform [154.64 - 155.40]
#   Word:  and [155.40 - 155.62]
#   Word:  understand [155.62 - 156.12]
#   Word:  all [156.12 - 156.66]
#   Word:  this [156.66 - 156.86]
#   Word:  voice [156.86 - 157.12]
#   Word:  and [157.12 - 157.32]
#   Word:  audio [157.32 - 157.56]
#   Word:  data [157.56 - 157.84]
#   Word:  in [157.84 - 158.16]
#   Word:  ways [158.16 - 158.42]
#   Word:  that [158.42 - 158.72]
# Segment [158.72 - 164.00]:  were not even possible a year or 18 months ago. So what we're seeing with the help of these new AI
#   Word:  were [158.72 - 158.96]
#   Word:  not [158.96 - 159.10]
#   Word:  even [159.10 - 159.24]
#   Word:  possible [159.24 - 159.72]
#   Word:  a [159.72 - 160.04]
#   Word:  year [160.04 - 160.28]
#   Word:  or [160.28 - 160.44]
#   Word:  18 [160.44 - 160.64]
#   Word:  months [160.64 - 160.84]
#   Word:  ago. [160.84 - 161.10]
#   Word:  So [161.40 - 161.56]
#   Word:  what [161.56 - 161.74]
#   Word:  we're [161.74 - 161.92]
#   Word:  seeing [161.92 - 162.24]
#   Word:  with [162.24 - 162.72]
#   Word:  the [162.72 - 162.86]
#   Word:  help [162.86 - 163.04]
#   Word:  of [163.04 - 163.26]
#   Word:  these [163.26 - 163.42]
#   Word:  new [163.42 - 163.60]
#   Word:  AI [163.60 - 164.00]
# Segment [164.00 - 169.46]:  models that we're creating at assembly, developers and organizations are just racing to build all
#   Word:  models [164.00 - 164.66]
#   Word:  that [164.66 - 165.12]
#   Word:  we're [165.12 - 165.48]
#   Word:  creating [165.48 - 165.72]
#   Word:  at [165.72 - 165.90]
#   Word:  assembly, [165.90 - 166.20]
#   Word:  developers [166.46 - 167.00]
#   Word:  and [167.00 - 167.22]
#   Word:  organizations [167.22 - 167.78]
#   Word:  are [167.78 - 168.14]
#   Word:  just [168.14 - 168.28]
#   Word:  racing [168.28 - 168.64]
#   Word:  to [168.64 - 168.88]
#   Word:  build [168.88 - 169.12]
#   Word:  all [169.12 - 169.46]
# Segment [169.46 - 175.36]:  these new applications, workflows, automations that leverage the voice data they have, either with
#   Word:  these [169.46 - 169.70]
#   Word:  new [169.70 - 170.06]
#   Word:  applications, [170.06 - 170.94]
#   Word:  workflows, [171.46 - 171.70]
#   Word:  automations [172.14 - 172.72]
#   Word:  that [172.72 - 173.00]
#   Word:  leverage [173.00 - 173.40]
#   Word:  the [173.40 - 173.74]
#   Word:  voice [173.74 - 173.98]
#   Word:  data [173.98 - 174.26]
#   Word:  they [174.26 - 174.46]
#   Word:  have, [174.46 - 174.86]
#   Word:  either [174.96 - 175.20]
#   Word:  with [175.20 - 175.36]
# Segment [175.36 - 180.26]:  other organization or with other product to build really cool new products and services,
#   Word:  other [175.36 - 175.60]
#   Word:  organization [175.60 - 176.46]
#   Word:  or [176.46 - 176.94]
#   Word:  with [176.94 - 177.38]
#   Word:  other [177.38 - 177.52]
#   Word:  product [177.52 - 178.02]
#   Word:  to [178.02 - 178.20]
#   Word:  build [178.20 - 178.48]
#   Word:  really [178.48 - 178.88]
#   Word:  cool [178.88 - 179.08]
#   Word:  new [179.08 - 179.24]
#   Word:  products [179.24 - 179.58]
#   Word:  and [179.58 - 179.86]
#   Word:  services, [179.86 - 180.26]
# Segment [180.68 - 185.64]:  workflows that are just like taking off at the market. So at assembly, we're building the industry
#   Word:  workflows [180.68 - 181.02]
#   Word:  that [181.02 - 181.64]
#   Word:  are [181.64 - 181.76]
#   Word:  just [181.76 - 181.90]
#   Word:  like [181.90 - 182.00]
#   Word:  taking [182.00 - 182.28]
#   Word:  off [182.28 - 182.62]
#   Word:  at [182.62 - 182.74]
#   Word:  the [182.74 - 182.84]
#   Word:  market. [182.84 - 183.10]
#   Word:  So [183.66 - 183.72]
#   Word:  at [183.72 - 183.96]
#   Word:  assembly, [183.96 - 184.28]
#   Word:  we're [184.58 - 184.90]
#   Word:  building [184.90 - 185.10]
#   Word:  the [185.10 - 185.28]
#   Word:  industry [185.28 - 185.64]
# Segment [185.64 - 190.46]:  leading models for all those different apps and workflows, whether it's speech to text or speaker
#   Word:  leading [185.64 - 185.90]
#   Word:  models [185.90 - 186.32]
#   Word:  for [186.32 - 186.66]
#   Word:  all [186.66 - 186.92]
#   Word:  those [186.92 - 187.20]
#   Word:  different [187.20 - 187.52]
#   Word:  apps [187.52 - 188.12]
#   Word:  and [188.12 - 188.32]
#   Word:  workflows, [188.32 - 188.66]
#   Word:  whether [188.80 - 189.00]
#   Word:  it's [189.00 - 189.22]
#   Word:  speech [189.22 - 189.40]
#   Word:  to [189.40 - 189.62]
#   Word:  text [189.62 - 189.92]
#   Word:  or [189.92 - 190.14]
#   Word:  speaker [190.14 - 190.46]
# Segment [190.46 - 195.90]:  diarization or speech understanding capabilities to summarize voice data or extract entities or
#   Word:  diarization [190.46 - 191.08]
#   Word:  or [191.08 - 191.44]
#   Word:  speech [191.44 - 191.64]
#   Word:  understanding [191.64 - 191.90]
#   Word:  capabilities [191.90 - 192.86]
#   Word:  to [192.86 - 193.30]
#   Word:  summarize [193.30 - 193.84]
#   Word:  voice [193.84 - 194.14]
#   Word:  data [194.14 - 194.48]
#   Word:  or [194.48 - 194.74]
#   Word:  extract [194.74 - 195.06]
#   Word:  entities [195.06 - 195.64]
#   Word:  or [195.64 - 195.90]
# Segment [195.90 - 201.58]:  voice data or mask PII from phone calls for various types of automations that might be built.
#   Word:  voice [195.90 - 196.08]
#   Word:  data [196.08 - 196.36]
#   Word:  or [196.36 - 196.74]
#   Word:  mask [196.74 - 197.12]
#   Word:  PII [197.12 - 197.54]
#   Word:  from [197.54 - 197.96]
#   Word:  phone [197.96 - 198.18]
#   Word:  calls [198.18 - 198.58]
#   Word:  for [198.58 - 199.10]
#   Word:  various [199.10 - 199.78]
#   Word:  types [199.78 - 200.06]
#   Word:  of [200.06 - 200.36]
#   Word:  automations [200.36 - 200.92]
#   Word:  that [200.92 - 201.12]
#   Word:  might [201.12 - 201.22]
#   Word:  be [201.22 - 201.36]
#   Word:  built. [201.36 - 201.58]
# Segment [202.06 - 206.36]:  And we're exposing that through a super simple, super scalable API that's just constantly being
#   Word:  And [202.06 - 202.12]
#   Word:  we're [202.12 - 202.40]
#   Word:  exposing [202.40 - 202.74]
#   Word:  that [202.74 - 202.96]
#   Word:  through [202.96 - 203.10]
#   Word:  a [203.10 - 203.22]
#   Word:  super [203.22 - 203.50]
#   Word:  simple, [203.50 - 203.84]
#   Word:  super [203.94 - 204.14]
#   Word:  scalable [204.14 - 204.52]
#   Word:  API [204.52 - 204.84]
#   Word:  that's [204.84 - 205.36]
#   Word:  just [205.36 - 205.50]
#   Word:  constantly [205.50 - 206.08]
#   Word:  being [206.08 - 206.36]
# Segment [206.36 - 211.40]:  updated and constantly getting better. And so we're seeing a crazy amount of developers and
#   Word:  updated [206.36 - 206.84]
#   Word:  and [206.84 - 207.06]
#   Word:  constantly [207.06 - 207.48]
#   Word:  getting [207.48 - 207.82]
#   Word:  better. [207.82 - 208.14]
#   Word:  And [208.42 - 208.56]
#   Word:  so [208.56 - 208.74]
#   Word:  we're [208.74 - 208.90]
#   Word:  seeing [208.90 - 209.22]
#   Word:  a [209.22 - 209.70]
#   Word:  crazy [209.70 - 209.96]
#   Word:  amount [209.96 - 210.18]
#   Word:  of [210.18 - 210.30]
#   Word:  developers [210.30 - 210.70]
#   Word:  and [210.70 - 211.40]
# Segment [211.40 - 217.32]:  companies just built really cool apps and services on top of our API every day. It's really only
#   Word:  companies [211.40 - 211.94]
#   Word:  just [211.94 - 212.26]
#   Word:  built [212.26 - 212.56]
#   Word:  really [212.56 - 212.96]
#   Word:  cool [212.96 - 213.24]
#   Word:  apps [213.24 - 213.60]
#   Word:  and [213.60 - 213.88]
#   Word:  services [213.88 - 214.26]
#   Word:  on [214.26 - 214.72]
#   Word:  top [214.72 - 214.90]
#   Word:  of [214.90 - 215.08]
#   Word:  our [215.08 - 215.20]
#   Word:  API [215.20 - 215.46]
#   Word:  every [215.46 - 216.02]
#   Word:  day. [216.02 - 216.32]
#   Word:  It's [216.50 - 216.98]
#   Word:  really [216.98 - 217.12]
#   Word:  only [217.12 - 217.32]
# Segment [217.32 - 221.90]:  just getting started, especially with the model updates that we have planned over the second half
#   Word:  just [217.32 - 217.52]
#   Word:  getting [217.52 - 217.68]
#   Word:  started, [217.68 - 218.08]
#   Word:  especially [218.26 - 218.64]
#   Word:  with [218.64 - 218.94]
#   Word:  the [218.94 - 219.18]
#   Word:  model [219.18 - 219.74]
#   Word:  updates [219.74 - 220.10]
#   Word:  that [220.10 - 220.36]
#   Word:  we [220.36 - 220.50]
#   Word:  have [220.50 - 220.76]
#   Word:  planned [220.76 - 221.08]
#   Word:  over [221.08 - 221.34]
#   Word:  the [221.34 - 221.48]
#   Word:  second [221.48 - 221.70]
#   Word:  half [221.70 - 221.90]
# Segment [221.90 - 225.98]:  of the year that are coming out. They're really excited to launch to the developers on our API.
#   Word:  of [221.90 - 222.06]
#   Word:  the [222.06 - 222.12]
#   Word:  year [222.12 - 222.22]
#   Word:  that [222.22 - 222.34]
#   Word:  are [222.34 - 222.44]
#   Word:  coming [222.44 - 222.64]
#   Word:  out. [222.64 - 222.92]
#   Word:  They're [223.10 - 223.26]
#   Word:  really [223.26 - 223.44]
#   Word:  excited [223.44 - 223.74]
#   Word:  to [223.74 - 223.98]
#   Word:  launch [223.98 - 224.34]
#   Word:  to [224.34 - 224.82]
#   Word:  the [224.82 - 225.06]
#   Word:  developers [225.06 - 225.44]
#   Word:  on [225.44 - 225.62]
#   Word:  our [225.62 - 225.72]
#   Word:  API. [225.72 - 225.98]
# Segment [226.44 - 233.28]:  Okay, constantly updated speech AI models at your fingertips, well at your API fingertips, that is.
#   Word:  Okay, [226.44 - 226.86]
#   Word:  constantly [227.06 - 227.52]
#   Word:  updated [227.52 - 228.06]
#   Word:  speech [228.06 - 228.56]
#   Word:  AI [228.56 - 229.02]
#   Word:  models [229.02 - 229.52]
#   Word:  at [229.52 - 229.92]
#   Word:  your [229.92 - 230.06]
#   Word:  fingertips, [230.06 - 230.50]
#   Word:  well [230.80 - 230.92]
#   Word:  at [230.92 - 231.26]
#   Word:  your [231.26 - 231.42]
#   Word:  API [231.42 - 231.94]
#   Word:  fingertips, [231.94 - 232.58]
#   Word:  that [232.92 - 232.96]
#   Word:  is. [232.96 - 233.28]
# Segment [233.62 - 238.46]:  A good next step is to go to their playground. You can test out their models for free right there
#   Word:  A [233.62 - 233.70]
#   Word:  good [233.70 - 233.90]
#   Word:  next [233.90 - 234.06]
#   Word:  step [234.06 - 234.32]
#   Word:  is [234.32 - 234.48]
#   Word:  to [234.48 - 234.64]
#   Word:  go [234.64 - 234.84]
#   Word:  to [234.84 - 235.04]
#   Word:  their [235.04 - 235.24]
#   Word:  playground. [235.24 - 235.72]
#   Word:  You [235.94 - 235.94]
#   Word:  can [235.94 - 236.08]
#   Word:  test [236.08 - 236.42]
#   Word:  out [236.42 - 236.74]
#   Word:  their [236.74 - 236.90]
#   Word:  models [236.90 - 237.30]
#   Word:  for [237.30 - 237.48]
#   Word:  free [237.48 - 237.88]
#   Word:  right [237.88 - 238.34]
#   Word:  there [238.34 - 238.46]
# Segment [238.46 - 244.60]:  in the browser, or you can get started with a $50 credit at assemblyai.com slash practical AI.
#   Word:  in [238.46 - 238.52]
#   Word:  the [238.52 - 238.58]
#   Word:  browser, [238.58 - 238.94]
#   Word:  or [238.94 - 239.56]
#   Word:  you [239.56 - 239.68]
#   Word:  can [239.68 - 239.78]
#   Word:  get [239.78 - 239.86]
#   Word:  started [239.86 - 240.00]
#   Word:  with [240.00 - 240.14]
#   Word:  a [240.14 - 240.24]
#   Word:  $50 [240.24 - 240.60]
#   Word:  credit [240.60 - 241.06]
#   Word:  at [241.06 - 241.58]
#   Word:  assemblyai [241.58 - 242.54]
#   Word: .com [242.54 - 243.20]
#   Word:  slash [243.20 - 243.48]
#   Word:  practical [243.48 - 244.02]
#   Word:  AI. [244.02 - 244.60]
# Segment [244.60 - 249.30]:  Again, that's assemblyai.com slash practical AI.
#   Word:  Again, [244.60 - 245.42]
#   Word:  that's [245.52 - 245.68]
#   Word:  assemblyai [245.68 - 246.72]
#   Word: .com [246.72 - 247.80]
#   Word:  slash [247.80 - 248.22]
#   Word:  practical [248.22 - 248.74]
#   Word:  AI. [248.74 - 249.30]
# Segment [260.60 - 267.58]:  Welcome to another fully connected episode of the Practical AI Podcast. This is Daniel
#   Word:  Welcome [260.48 - 260.88]
#   Word:  to [260.88 - 261.30]
#   Word:  another [261.30 - 262.04]
#   Word:  fully [262.04 - 262.68]
#   Word:  connected [262.68 - 263.20]
#   Word:  episode [263.20 - 263.92]
#   Word:  of [263.92 - 264.28]
#   Word:  the [264.28 - 264.46]
#   Word:  Practical [264.46 - 265.02]
#   Word:  AI [265.02 - 265.34]
#   Word:  Podcast. [265.34 - 265.98]
#   Word:  This [266.50 - 266.90]
#   Word:  is [266.90 - 267.26]
#   Word:  Daniel [267.26 - 267.58]
# Segment [267.58 - 273.56]:  Whiteknack. I am the CEO and founder at Prediction Guard and I'm joined by my co-host,
#   Word:  Whiteknack. [267.58 - 268.10]
#   Word:  I [268.24 - 268.32]
#   Word:  am [268.32 - 268.46]
#   Word:  the [268.46 - 268.68]
#   Word:  CEO [268.68 - 269.40]
#   Word:  and [269.40 - 269.92]
#   Word:  founder [269.92 - 270.48]
#   Word:  at [270.48 - 270.74]
#   Word:  Prediction [270.74 - 271.08]
#   Word:  Guard [271.08 - 271.40]
#   Word:  and [271.40 - 271.70]
#   Word:  I'm [271.70 - 271.88]
#   Word:  joined [271.88 - 272.16]
#   Word:  by [272.16 - 272.92]
#   Word:  my [272.92 - 273.08]
#   Word:  co [273.08 - 273.32]
#   Word: -host, [273.32 - 273.56]
# Segment [273.56 - 279.36]:  Chris Benson, who is a principal AI research engineer at Lockheed Martin. In these fully
#   Word:  Chris [273.56 - 273.78]
#   Word:  Benson, [273.78 - 274.08]
#   Word:  who [274.40 - 274.58]
#   Word:  is [274.58 - 274.76]
#   Word:  a [274.76 - 274.96]
#   Word:  principal [274.96 - 275.46]
#   Word:  AI [275.46 - 275.94]
#   Word:  research [275.94 - 276.42]
#   Word:  engineer [276.42 - 276.94]
#   Word:  at [276.94 - 277.14]
#   Word:  Lockheed [277.14 - 277.56]
#   Word:  Martin. [277.56 - 277.80]
#   Word:  In [278.46 - 278.56]
#   Word:  these [278.56 - 278.82]
#   Word:  fully [278.82 - 279.36]
# Segment [279.36 - 284.64]:  connected episodes, we try to keep you fully connected with everything that's happening in the
#   Word:  connected [279.36 - 279.80]
#   Word:  episodes, [279.80 - 280.36]
#   Word:  we [280.48 - 280.56]
#   Word:  try [280.56 - 280.76]
#   Word:  to [280.76 - 280.88]
#   Word:  keep [280.88 - 281.08]
#   Word:  you [281.08 - 281.36]
#   Word:  fully [281.36 - 282.24]
#   Word:  connected [282.24 - 282.70]
#   Word:  with [282.70 - 283.02]
#   Word:  everything [283.02 - 283.42]
#   Word:  that's [283.42 - 283.76]
#   Word:  happening [283.76 - 284.10]
#   Word:  in [284.10 - 284.46]
#   Word:  the [284.46 - 284.64]
# Segment [284.64 - 291.12]:  machine learning and data science and AI worlds and hopefully share some things with you that'll
#   Word:  machine [284.64 - 285.34]
#   Word:  learning [285.34 - 285.72]
#   Word:  and [285.72 - 286.06]
#   Word:  data [286.06 - 286.34]
#   Word:  science [286.34 - 286.86]
#   Word:  and [286.86 - 287.06]
#   Word:  AI [287.06 - 287.34]
#   Word:  worlds [287.34 - 288.04]
#   Word:  and [288.04 - 289.04]
#   Word:  hopefully [289.04 - 289.52]
#   Word:  share [289.52 - 289.88]
#   Word:  some [289.88 - 290.10]
#   Word:  things [290.10 - 290.34]
#   Word:  with [290.34 - 290.64]
#   Word:  you [290.64 - 290.84]
#   Word:  that'll [290.84 - 291.12]
# Segment [291.12 - 297.58]:  help you level up your machine learning and AI game. How you doing, Chris? It'll be fun to catch
#   Word:  help [291.12 - 291.38]
#   Word:  you [291.38 - 291.62]
#   Word:  level [291.62 - 292.06]
#   Word:  up [292.06 - 292.38]
#   Word:  your [292.38 - 292.60]
#   Word:  machine [292.60 - 293.40]
#   Word:  learning [293.40 - 293.76]
#   Word:  and [293.76 - 293.96]
#   Word:  AI [293.96 - 294.18]
#   Word:  game. [294.18 - 294.60]
#   Word:  How [295.20 - 295.32]
#   Word:  you [295.32 - 295.42]
#   Word:  doing, [295.42 - 295.62]
#   Word:  Chris? [295.70 - 295.84]
#   Word:  It'll [296.26 - 296.68]
#   Word:  be [296.68 - 296.82]
#   Word:  fun [296.82 - 297.06]
#   Word:  to [297.06 - 297.30]
#   Word:  catch [297.30 - 297.58]
# Segment [297.58 - 302.18]:  up on a few things that are that have been happening over the past couple weeks today.
#   Word:  up [297.58 - 297.78]
#   Word:  on [297.78 - 297.92]
#   Word:  a [297.92 - 298.02]
#   Word:  few [298.02 - 298.20]
#   Word:  things [298.20 - 298.60]
#   Word:  that [298.60 - 298.86]
#   Word:  are [298.86 - 299.06]
#   Word:  that [299.06 - 299.40]
#   Word:  have [299.40 - 299.98]
#   Word:  been [299.98 - 300.18]
#   Word:  happening [300.18 - 300.54]
#   Word:  over [300.54 - 300.84]
#   Word:  the [300.84 - 301.02]
#   Word:  past [301.02 - 301.32]
#   Word:  couple [301.32 - 301.56]
#   Word:  weeks [301.56 - 301.84]
#   Word:  today. [301.84 - 302.18]
# Segment [302.18 - 308.00]:  There are so much going on. Oh my gosh. Always. We'll have to pick and choose what we have time
#   Word:  There [302.18 - 302.76]
#   Word:  are [302.76 - 302.94]
#   Word:  so [302.94 - 303.16]
#   Word:  much [303.16 - 303.48]
#   Word:  going [303.48 - 303.72]
#   Word:  on. [303.72 - 304.06]
#   Word:  Oh [304.12 - 304.34]
#   Word:  my [304.34 - 304.66]
#   Word:  gosh. [304.66 - 304.96]
#   Word:  Always. [305.26 - 305.82]
#   Word:  We'll [306.10 - 306.40]
#   Word:  have [306.40 - 306.40]
#   Word:  to [306.40 - 306.60]
#   Word:  pick [306.60 - 306.72]
#   Word:  and [306.72 - 306.90]
#   Word:  choose [306.90 - 307.22]
#   Word:  what [307.22 - 307.46]
#   Word:  we [307.46 - 307.60]
#   Word:  have [307.60 - 307.72]
#   Word:  time [307.72 - 308.00]
# Segment [308.00 - 313.16]:  to hit here. How are you hearing about AI things these days, Chris? Maybe that's
#   Word:  to [308.00 - 308.16]
#   Word:  hit [308.16 - 308.36]
#   Word:  here. [308.36 - 308.62]
#   Word:  How [308.98 - 309.22]
#   Word:  are [309.22 - 309.36]
#   Word:  you [309.36 - 309.54]
#   Word:  hearing [309.54 - 309.94]
#   Word:  about [309.94 - 310.26]
#   Word:  AI [310.26 - 310.52]
#   Word:  things [310.52 - 310.96]
#   Word:  these [310.96 - 311.30]
#   Word:  days, [311.30 - 311.70]
#   Word:  Chris? [311.90 - 312.08]
#   Word:  Maybe [312.32 - 312.68]
#   Word:  that's [312.68 - 313.16]
# Segment [313.78 - 320.40]:  even something that people might be interested in knowing. Maybe we've talked about this a few
#   Word:  even [313.78 - 314.06]
#   Word:  something [314.06 - 314.50]
#   Word:  that [314.50 - 314.98]
#   Word:  people [314.98 - 315.60]
#   Word:  might [315.60 - 316.04]
#   Word:  be [316.04 - 316.76]
#   Word:  interested [316.76 - 317.28]
#   Word:  in [317.28 - 317.58]
#   Word:  knowing. [317.58 - 317.82]
#   Word:  Maybe [318.32 - 318.54]
#   Word:  we've [318.54 - 319.40]
#   Word:  talked [319.40 - 319.60]
#   Word:  about [319.60 - 319.84]
#   Word:  this [319.84 - 320.10]
#   Word:  a [320.10 - 320.24]
#   Word:  few [320.24 - 320.40]
# Segment [320.40 - 327.46]:  times on the show, but there may be new listeners who kind of got into the show after Gen AI stuff
#   Word:  times [320.40 - 320.76]
#   Word:  on [320.76 - 321.08]
#   Word:  the [321.08 - 321.24]
#   Word:  show, [321.24 - 321.64]
#   Word:  but [321.96 - 322.28]
#   Word:  there [322.28 - 322.56]
#   Word:  may [322.56 - 322.80]
#   Word:  be [322.80 - 322.92]
#   Word:  new [322.92 - 323.12]
#   Word:  listeners [323.12 - 323.50]
#   Word:  who [323.50 - 323.88]
#   Word:  kind [323.88 - 324.16]
#   Word:  of [324.16 - 324.30]
#   Word:  got [324.30 - 324.48]
#   Word:  into [324.48 - 324.74]
#   Word:  the [324.74 - 324.94]
#   Word:  show [324.94 - 325.28]
#   Word:  after [325.28 - 325.76]
#   Word:  Gen [325.76 - 326.72]
#   Word:  AI [326.72 - 326.92]
#   Word:  stuff [326.92 - 327.46]
# Segment [327.46 - 332.04]:  and they're trying to figure out where to keep up with news and learn things.
#   Word:  and [327.46 - 327.92]
#   Word:  they're [327.92 - 328.60]
#   Word:  trying [328.60 - 328.80]
#   Word:  to [328.80 - 328.90]
#   Word:  figure [328.90 - 329.12]
#   Word:  out [329.12 - 329.30]
#   Word:  where [329.30 - 329.50]
#   Word:  to [329.50 - 329.68]
#   Word:  keep [329.68 - 330.00]
#   Word:  up [330.00 - 330.24]
#   Word:  with [330.24 - 330.48]
#   Word:  news [330.48 - 331.02]
#   Word:  and [331.02 - 331.34]
#   Word:  learn [331.34 - 331.60]
#   Word:  things. [331.60 - 332.04]
# Segment [332.36 - 335.56]:  The questions, the inverse, it's like, where are you not hearing about it because we're
#   Word:  The [332.36 - 332.68]
#   Word:  questions, [332.68 - 333.00]
#   Word:  the [333.34 - 333.42]
#   Word:  inverse, [333.42 - 333.64]
#   Word:  it's [333.82 - 333.90]
#   Word:  like, [333.90 - 334.02]
#   Word:  where [334.04 - 334.14]
#   Word:  are [334.14 - 334.24]
#   Word:  you [334.24 - 334.30]
#   Word:  not [334.30 - 334.54]
#   Word:  hearing [334.54 - 334.76]
#   Word:  about [334.76 - 335.04]
#   Word:  it [335.04 - 335.20]
#   Word:  because [335.20 - 335.34]
#   Word:  we're [335.34 - 335.56]
# Segment [335.56 - 339.54]:  getting it from every angle? Or where do you, how do you filter through the noise?
#   Word:  getting [335.56 - 335.82]
#   Word:  it [335.82 - 336.00]
#   Word:  from [336.00 - 336.14]
#   Word:  every [336.14 - 336.38]
#   Word:  angle? [336.38 - 336.70]
#   Word:  Or [337.02 - 337.18]
#   Word:  where [337.18 - 337.38]
#   Word:  do [337.38 - 337.54]
#   Word:  you, [337.54 - 337.68]
#   Word:  how [337.98 - 338.16]
#   Word:  do [338.16 - 338.20]
#   Word:  you [338.20 - 338.30]
#   Word:  filter [338.30 - 338.62]
#   Word:  through [338.62 - 338.92]
#   Word:  the [338.92 - 339.14]
#   Word:  noise? [339.14 - 339.54]
# Segment [339.92 - 345.52]:  That's the issue there. Is there so much noise now? There's so many, like, you know, I,
#   Word:  That's [339.92 - 340.36]
#   Word:  the [340.36 - 340.54]
#   Word:  issue [340.54 - 340.88]
#   Word:  there. [340.88 - 341.16]
#   Word:  Is [341.42 - 341.52]
#   Word:  there [341.52 - 341.66]
#   Word:  so [341.66 - 342.10]
#   Word:  much [342.10 - 342.36]
#   Word:  noise [342.36 - 342.66]
#   Word:  now? [342.66 - 343.00]
#   Word:  There's [343.22 - 343.46]
#   Word:  so [343.46 - 343.70]
#   Word:  many, [343.70 - 343.90]
#   Word:  like, [344.24 - 344.38]
#   Word:  you [344.58 - 344.90]
#   Word:  know, [344.90 - 345.02]
#   Word:  I, [345.26 - 345.52]
# Segment [346.10 - 351.14]:  you know, I know both of us have our kind of workflow on how we're consuming new things going
#   Word:  you [346.10 - 346.58]
#   Word:  know, [346.58 - 346.68]
#   Word:  I [346.70 - 346.76]
#   Word:  know [346.76 - 346.88]
#   Word:  both [346.88 - 347.10]
#   Word:  of [347.10 - 347.24]
#   Word:  us [347.24 - 347.42]
#   Word:  have [347.42 - 347.64]
#   Word:  our [347.64 - 347.96]
#   Word:  kind [347.96 - 348.36]
#   Word:  of [348.36 - 348.46]
#   Word:  workflow [348.46 - 348.96]
#   Word:  on [348.96 - 349.38]
#   Word:  how [349.38 - 349.58]
#   Word:  we're [349.58 - 349.72]
#   Word:  consuming [349.72 - 350.12]
#   Word:  new [350.12 - 350.50]
#   Word:  things [350.50 - 350.84]
#   Word:  going [350.84 - 351.14]
# Segment [351.14 - 357.04]:  on out there and have for many years as we've been doing the show. And I think there's so much more
#   Word:  on [351.14 - 351.38]
#   Word:  out [351.38 - 351.54]
#   Word:  there [351.54 - 351.82]
#   Word:  and [351.82 - 352.12]
#   Word:  have [352.12 - 352.86]
#   Word:  for [352.86 - 353.06]
#   Word:  many [353.06 - 353.26]
#   Word:  years [353.26 - 353.66]
#   Word:  as [353.66 - 353.88]
#   Word:  we've [353.88 - 354.06]
#   Word:  been [354.06 - 354.14]
#   Word:  doing [354.14 - 354.28]
#   Word:  the [354.28 - 354.48]
#   Word:  show. [354.48 - 354.78]
#   Word:  And [355.10 - 355.40]
#   Word:  I [355.40 - 355.52]
#   Word:  think [355.52 - 355.68]
#   Word:  there's [355.68 - 355.98]
#   Word:  so [355.98 - 356.34]
#   Word:  much [356.34 - 356.64]
#   Word:  more [356.64 - 357.04]
# Segment [357.46 - 364.00]:  that is coming in and the quality varies hugely in terms of how you might do it. And I mean,
#   Word:  that [357.46 - 357.66]
#   Word:  is [357.66 - 357.82]
#   Word:  coming [357.82 - 358.04]
#   Word:  in [358.04 - 358.44]
#   Word:  and [358.44 - 358.90]
#   Word:  the [358.90 - 359.40]
#   Word:  quality [359.40 - 359.78]
#   Word:  varies [359.78 - 360.24]
#   Word:  hugely [360.24 - 361.38]
#   Word:  in [361.38 - 362.08]
#   Word:  terms [362.08 - 362.32]
#   Word:  of [362.32 - 362.74]
#   Word:  how [362.74 - 363.12]
#   Word:  you [363.12 - 363.30]
#   Word:  might [363.30 - 363.44]
#   Word:  do [363.44 - 363.62]
#   Word:  it. [363.62 - 363.76]
#   Word:  And [363.86 - 363.86]
#   Word:  I [363.86 - 363.98]
#   Word:  mean, [363.98 - 364.00]
# Segment [364.08 - 369.40]:  I know we're going to talk about a few topics today. And I know that on at least one of those
#   Word:  I [364.08 - 364.26]
#   Word:  know [364.26 - 364.38]
#   Word:  we're [364.38 - 364.54]
#   Word:  going [364.54 - 364.64]
#   Word:  to [364.64 - 364.68]
#   Word:  talk [364.68 - 364.88]
#   Word:  about [364.88 - 365.04]
#   Word:  a [365.04 - 365.14]
#   Word:  few [365.14 - 365.30]
#   Word:  topics [365.30 - 365.64]
#   Word:  today. [365.64 - 366.66]
#   Word:  And [367.32 - 367.72]
#   Word:  I [367.72 - 367.88]
#   Word:  know [367.88 - 368.04]
#   Word:  that [368.04 - 368.20]
#   Word:  on [368.20 - 368.42]
#   Word:  at [368.42 - 368.60]
#   Word:  least [368.60 - 368.74]
#   Word:  one [368.74 - 368.94]
#   Word:  of [368.94 - 369.04]
#   Word:  those [369.04 - 369.40]
# Segment [369.94 - 375.04]:  to be seen in a few minutes, some of the info is kind of straight down the line, gives you the
#   Word:  to [369.94 - 370.16]
#   Word:  be [370.16 - 370.30]
#   Word:  seen [370.30 - 370.56]
#   Word:  in [370.56 - 370.68]
#   Word:  a [370.68 - 370.78]
#   Word:  few [370.78 - 370.88]
#   Word:  minutes, [370.88 - 371.18]
#   Word:  some [371.32 - 371.90]
#   Word:  of [371.90 - 372.04]
#   Word:  the [372.04 - 372.14]
#   Word:  info [372.14 - 372.48]
#   Word:  is [372.48 - 373.02]
#   Word:  kind [373.02 - 373.28]
#   Word:  of [373.28 - 373.36]
#   Word:  straight [373.36 - 373.64]
#   Word:  down [373.64 - 373.86]
#   Word:  the [373.86 - 373.96]
#   Word:  line, [373.96 - 374.30]
#   Word:  gives [374.32 - 374.76]
#   Word:  you [374.76 - 374.92]
#   Word:  the [374.92 - 375.04]
# Segment [375.04 - 380.82]:  facts and others are very hypey. We've talked a lot about how hypey things are. But I think that's
#   Word:  facts [375.04 - 375.54]
#   Word:  and [375.54 - 375.88]
#   Word:  others [375.88 - 376.16]
#   Word:  are [376.16 - 376.50]
#   Word:  very [376.50 - 377.28]
#   Word:  hypey. [377.28 - 377.74]
#   Word:  We've [377.80 - 377.94]
#   Word:  talked [377.94 - 378.10]
#   Word:  a [378.10 - 378.28]
#   Word:  lot [378.28 - 378.48]
#   Word:  about [378.48 - 378.70]
#   Word:  how [378.70 - 378.88]
#   Word:  hypey [378.88 - 379.22]
#   Word:  things [379.22 - 379.34]
#   Word:  are. [379.34 - 379.66]
#   Word:  But [380.02 - 380.30]
#   Word:  I [380.30 - 380.48]
#   Word:  think [380.48 - 380.60]
#   Word:  that's [380.60 - 380.82]
# Segment [380.82 - 386.38]:  one of the challenges with this field is moving so fast and it's in, it's just one of the dominant
#   Word:  one [380.82 - 380.96]
#   Word:  of [380.96 - 381.02]
#   Word:  the [381.02 - 381.08]
#   Word:  challenges [381.08 - 381.48]
#   Word:  with [381.48 - 381.76]
#   Word:  this [381.76 - 381.94]
#   Word:  field [381.94 - 382.14]
#   Word:  is [382.14 - 382.28]
#   Word:  moving [382.28 - 382.48]
#   Word:  so [382.48 - 382.78]
#   Word:  fast [382.78 - 383.24]
#   Word:  and [383.24 - 383.90]
#   Word:  it's [383.90 - 384.12]
#   Word:  in, [384.12 - 384.30]
#   Word:  it's [384.86 - 385.26]
#   Word:  just [385.26 - 385.44]
#   Word:  one [385.44 - 385.86]
#   Word:  of [385.86 - 385.94]
#   Word:  the [385.94 - 386.04]
#   Word:  dominant [386.04 - 386.38]
# Segment [386.38 - 391.84]:  topics in mainstream media now. And you have a lot of folks out there reporting on it, some of
#   Word:  topics [386.38 - 386.80]
#   Word:  in [386.80 - 387.06]
#   Word:  mainstream [387.06 - 387.38]
#   Word:  media [387.38 - 387.84]
#   Word:  now. [387.84 - 388.10]
#   Word:  And [388.24 - 388.26]
#   Word:  you [388.26 - 388.34]
#   Word:  have [388.34 - 388.46]
#   Word:  a [388.46 - 388.54]
#   Word:  lot [388.54 - 388.70]
#   Word:  of [388.70 - 388.80]
#   Word:  folks [388.80 - 389.06]
#   Word:  out [389.06 - 389.34]
#   Word:  there [389.34 - 389.62]
#   Word:  reporting [389.62 - 390.52]
#   Word:  on [390.52 - 390.82]
#   Word:  it, [390.82 - 391.00]
#   Word:  some [391.16 - 391.70]
#   Word:  of [391.70 - 391.84]
# Segment [391.84 - 397.38]:  which knows something about it, some of which don't know as much. So yeah, the filtering is the big
#   Word:  which [391.84 - 392.06]
#   Word:  knows [392.06 - 392.72]
#   Word:  something [392.72 - 393.02]
#   Word:  about [393.02 - 393.28]
#   Word:  it, [393.28 - 393.46]
#   Word:  some [393.56 - 393.72]
#   Word:  of [393.72 - 393.92]
#   Word:  which [393.92 - 394.12]
#   Word:  don't [394.12 - 394.34]
#   Word:  know [394.34 - 394.56]
#   Word:  as [394.56 - 394.68]
#   Word:  much. [394.68 - 394.94]
#   Word:  So [395.34 - 395.34]
#   Word:  yeah, [395.34 - 396.30]
#   Word:  the [396.50 - 396.62]
#   Word:  filtering [396.62 - 396.92]
#   Word:  is [396.92 - 397.16]
#   Word:  the [397.16 - 397.26]
#   Word:  big [397.26 - 397.38]
# Segment [397.38 - 403.72]:  challenge. It's been slightly different for me, I think in the sense that, well, one, you know,
#   Word:  challenge. [397.38 - 397.76]
#   Word:  It's [398.30 - 398.42]
#   Word:  been [398.42 - 398.76]
#   Word:  slightly [398.76 - 399.74]
#   Word:  different [399.74 - 400.26]
#   Word:  for [400.26 - 400.52]
#   Word:  me, [400.52 - 400.72]
#   Word:  I [400.74 - 400.86]
#   Word:  think [400.86 - 401.12]
#   Word:  in [401.12 - 401.44]
#   Word:  the [401.44 - 401.62]
#   Word:  sense [401.62 - 401.90]
#   Word:  that, [401.90 - 402.30]
#   Word:  well, [402.38 - 402.92]
#   Word:  one, [402.96 - 403.26]
#   Word:  you [403.58 - 403.60]
#   Word:  know, [403.60 - 403.72]
# Segment [403.78 - 411.46]:  I founded a company. So my, my attentions are slightly maybe distracted with one thing or another,
#   Word:  I [403.78 - 403.82]
#   Word:  founded [403.82 - 404.58]
#   Word:  a [404.58 - 404.96]
#   Word:  company. [404.96 - 405.54]
#   Word:  So [405.80 - 405.88]
#   Word:  my, [405.88 - 406.18]
#   Word:  my [406.24 - 406.52]
#   Word:  attentions [406.52 - 407.08]
#   Word:  are [407.08 - 407.38]
#   Word:  slightly [407.38 - 408.06]
#   Word:  maybe [408.06 - 408.70]
#   Word:  distracted [408.70 - 409.58]
#   Word:  with [409.58 - 410.28]
#   Word:  one [410.28 - 410.48]
#   Word:  thing [410.48 - 410.78]
#   Word:  or [410.78 - 411.14]
#   Word:  another, [411.14 - 411.46]
# Segment [411.46 - 418.88]:  or maybe exposed to things in different ways. But also, I think my habits online have changed
#   Word:  or [411.46 - 412.16]
#   Word:  maybe [412.16 - 412.40]
#   Word:  exposed [412.40 - 412.80]
#   Word:  to [412.80 - 413.32]
#   Word:  things [413.32 - 413.68]
#   Word:  in [413.68 - 413.88]
#   Word:  different [413.88 - 414.16]
#   Word:  ways. [414.16 - 414.50]
#   Word:  But [414.92 - 415.14]
#   Word:  also, [415.14 - 415.50]
#   Word:  I [415.90 - 416.64]
#   Word:  think [416.64 - 416.78]
#   Word:  my [416.78 - 416.96]
#   Word:  habits [416.96 - 417.38]
#   Word:  online [417.38 - 417.96]
#   Word:  have [417.96 - 418.38]
#   Word:  changed [418.38 - 418.88]
# Segment [418.88 - 427.88]:  even over the past year or so. Whereas I was maybe more, at least, not always posting, but,
#   Word:  even [418.88 - 419.16]
#   Word:  over [419.16 - 419.46]
#   Word:  the [419.46 - 419.64]
#   Word:  past [419.64 - 420.10]
#   Word:  year [420.10 - 421.00]
#   Word:  or [421.00 - 421.32]
#   Word:  so. [421.32 - 421.66]
#   Word:  Whereas [421.92 - 422.42]
#   Word:  I [422.42 - 422.86]
#   Word:  was [422.86 - 423.40]
#   Word:  maybe [423.40 - 423.68]
#   Word:  more, [423.68 - 424.18]
#   Word:  at [425.08 - 425.24]
#   Word:  least, [425.24 - 425.58]
#   Word:  not [425.74 - 426.56]
#   Word:  always [426.56 - 426.94]
#   Word:  posting, [426.94 - 427.46]
#   Word:  but, [427.88 - 427.88]
# Segment [427.90 - 436.78]:  but looking kind of for things on Twitter or X as it is now and seeing, you know, a pretty active
#   Word:  but [427.90 - 428.10]
#   Word:  looking [428.10 - 428.44]
#   Word:  kind [428.44 - 429.08]
#   Word:  of [429.08 - 429.18]
#   Word:  for [429.18 - 429.36]
#   Word:  things [429.36 - 429.76]
#   Word:  on [429.76 - 430.40]
#   Word:  Twitter [430.40 - 431.38]
#   Word:  or [431.38 - 431.94]
#   Word:  X [431.94 - 432.48]
#   Word:  as [432.48 - 433.44]
#   Word:  it [433.44 - 433.58]
#   Word:  is [433.58 - 433.74]
#   Word:  now [433.74 - 434.08]
#   Word:  and [434.08 - 434.48]
#   Word:  seeing, [434.48 - 434.90]
#   Word:  you [435.26 - 435.64]
#   Word:  know, [435.64 - 435.78]
#   Word:  a [435.94 - 436.00]
#   Word:  pretty [436.00 - 436.16]
#   Word:  active [436.16 - 436.78]
# Segment [437.58 - 444.76]:  AI community there, of course, where I had, well, you as well, you know, we both kind of had
#   Word:  AI [437.54 - 437.82]
#   Word:  community [437.82 - 438.38]
#   Word:  there, [438.38 - 438.82]
#   Word:  of [438.94 - 438.96]
#   Word:  course, [438.96 - 439.24]
#   Word:  where [439.46 - 439.64]
#   Word:  I [439.64 - 440.48]
#   Word:  had, [440.48 - 440.92]
#   Word:  well, [441.36 - 441.66]
#   Word:  you [441.84 - 441.96]
#   Word:  as [441.96 - 442.16]
#   Word:  well, [442.16 - 442.50]
#   Word:  you [442.92 - 443.52]
#   Word:  know, [443.52 - 443.66]
#   Word:  we [443.80 - 443.92]
#   Word:  both [443.92 - 444.34]
#   Word:  kind [444.34 - 444.50]
#   Word:  of [444.50 - 444.60]
#   Word:  had [444.60 - 444.76]
# Segment [444.76 - 450.20]:  different journeys into this, but definitely I had this sort of more background on the data
#   Word:  different [444.76 - 445.06]
#   Word:  journeys [445.06 - 445.40]
#   Word:  into [445.40 - 445.66]
#   Word:  this, [445.66 - 445.92]
#   Word:  but [445.98 - 446.12]
#   Word:  definitely [446.12 - 446.48]
#   Word:  I [446.48 - 446.72]
#   Word:  had [446.72 - 447.00]
#   Word:  this [447.00 - 447.22]
#   Word:  sort [447.22 - 447.42]
#   Word:  of [447.42 - 447.62]
#   Word:  more [447.62 - 448.40]
#   Word:  background [448.40 - 449.44]
#   Word:  on [449.44 - 449.78]
#   Word:  the [449.78 - 449.94]
#   Word:  data [449.94 - 450.20]
# Segment [450.20 - 458.86]:  science thing and a lot of kind of data science discussion was at least in my world happening
#   Word:  science [450.20 - 450.66]
#   Word:  thing [450.66 - 451.06]
#   Word:  and [451.06 - 451.38]
#   Word:  a [451.38 - 451.62]
#   Word:  lot [451.62 - 451.78]
#   Word:  of [451.78 - 452.06]
#   Word:  kind [452.06 - 452.84]
#   Word:  of [452.84 - 453.02]
#   Word:  data [453.02 - 453.52]
#   Word:  science [453.52 - 454.20]
#   Word:  discussion [454.20 - 455.40]
# ...
#   Word:  They [2851.58 - 2851.68]
#   Word:  of [2851.68 - 2851.80]
#   Word:  course [2851.80 - 2851.98]
#   Word:  have [2851.98 - 2852.18]
#   Word:  great [2852.18 - 2852.48]
# Segment [2852.48 - 2859.32]:  documentation and examples on their site as well. I'll also mention if you're hearing this
#   Word:  documentation [2852.48 - 2853.26]
#   Word:  and [2853.26 - 2853.60]
#   Word:  examples [2853.60 - 2854.10]
#   Word:  on [2854.10 - 2854.42]
#   Word:  their [2854.42 - 2854.62]
#   Word:  site [2854.62 - 2855.62]
#   Word:  as [2855.62 - 2855.90]
#   Word:  well. [2855.90 - 2856.16]
#   Word:  I'll [2856.62 - 2856.84]
#   Word:  also [2856.84 - 2857.12]
#   Word:  mention [2857.12 - 2857.48]
#   Word:  if [2857.48 - 2858.64]
#   Word:  you're [2858.64 - 2858.84]
#   Word:  hearing [2858.84 - 2859.10]
#   Word:  this [2859.10 - 2859.32]
# Segment [2859.32 - 2866.88]:  podcast right after it airs, I think there's still time for you. But Purdue University, which I'm
#   Word:  podcast [2859.32 - 2859.80]
#   Word:  right [2859.80 - 2860.20]
#   Word:  after [2860.20 - 2860.60]
#   Word:  it [2860.60 - 2860.80]
#   Word:  airs, [2860.80 - 2861.38]
#   Word:  I [2861.72 - 2861.86]
#   Word:  think [2861.86 - 2862.06]
#   Word:  there's [2862.06 - 2862.40]
#   Word:  still [2862.40 - 2862.66]
#   Word:  time [2862.66 - 2863.10]
#   Word:  for [2863.10 - 2863.40]
#   Word:  you. [2863.40 - 2863.64]
#   Word:  But [2863.98 - 2863.98]
#   Word:  Purdue [2863.98 - 2865.04]
#   Word:  University, [2865.04 - 2865.92]
#   Word:  which [2866.12 - 2866.30]
#   Word:  I'm [2866.30 - 2866.88]
# Segment [2866.88 - 2872.42]:  close here, but they're working with actually a bunch of partners, including commercial partners,
#   Word:  close [2866.88 - 2867.20]
#   Word:  here, [2867.20 - 2867.54]
#   Word:  but [2867.68 - 2867.76]
#   Word:  they're [2867.76 - 2868.00]
#   Word:  working [2868.00 - 2868.22]
#   Word:  with [2868.22 - 2868.56]
#   Word:  actually [2868.56 - 2869.10]
#   Word:  a [2869.10 - 2869.34]
#   Word:  bunch [2869.34 - 2869.80]
#   Word:  of [2869.80 - 2869.98]
#   Word:  partners, [2869.98 - 2870.46]
#   Word:  including [2870.58 - 2871.04]
#   Word:  commercial [2871.04 - 2872.02]
#   Word:  partners, [2872.02 - 2872.42]
# Segment [2872.42 - 2879.92]:  but they're running a data for good competition, which is close to Chris and I's heart. So they're
#   Word:  but [2872.42 - 2872.72]
#   Word:  they're [2872.72 - 2872.98]
#   Word:  running [2872.98 - 2873.38]
#   Word:  a [2873.38 - 2873.60]
#   Word:  data [2873.60 - 2873.92]
#   Word:  for [2873.92 - 2874.20]
#   Word:  good [2874.20 - 2874.54]
#   Word:  competition, [2874.54 - 2875.24]
#   Word:  which [2875.24 - 2875.64]
#   Word:  is [2875.64 - 2875.86]
#   Word:  close [2875.86 - 2876.44]
#   Word:  to [2876.44 - 2876.80]
#   Word:  Chris [2876.80 - 2877.42]
#   Word:  and [2877.42 - 2878.04]
#   Word:  I's [2878.04 - 2878.38]
#   Word:  heart. [2878.38 - 2878.66]
#   Word:  So [2879.14 - 2879.24]
#   Word:  they're [2879.24 - 2879.92]
# Segment [2879.92 - 2887.10]:  supporting the TAPS organization, which provides grief, counseling, and care for those that have
#   Word:  supporting [2879.92 - 2880.52]
#   Word:  the [2880.52 - 2881.42]
#   Word:  TAPS [2881.42 - 2882.08]
#   Word:  organization, [2882.08 - 2882.72]
#   Word:  which [2882.96 - 2883.10]
#   Word:  provides [2883.10 - 2883.60]
#   Word:  grief, [2883.60 - 2884.84]
#   Word:  counseling, [2885.34 - 2885.56]
#   Word:  and [2885.76 - 2885.84]
#   Word:  care [2885.84 - 2886.14]
#   Word:  for [2886.14 - 2886.42]
#   Word:  those [2886.42 - 2886.68]
#   Word:  that [2886.68 - 2886.90]
#   Word:  have [2886.90 - 2887.10]
# Segment [2887.10 - 2894.34]:  lost family members that served in the military. And so if you're interested in that, check it out.
#   Word:  lost [2887.10 - 2887.82]
#   Word:  family [2887.82 - 2888.24]
#   Word:  members [2888.24 - 2888.80]
#   Word:  that [2888.80 - 2889.74]
#   Word:  served [2889.74 - 2890.28]
#   Word:  in [2890.28 - 2890.44]
#   Word:  the [2890.44 - 2890.52]
#   Word:  military. [2890.52 - 2891.00]
#   Word:  And [2891.70 - 2892.20]
#   Word:  so [2892.20 - 2892.56]
#   Word:  if [2892.56 - 2892.76]
#   Word:  you're [2892.76 - 2892.90]
#   Word:  interested [2892.90 - 2893.26]
#   Word:  in [2893.26 - 2893.44]
#   Word:  that, [2893.44 - 2893.62]
#   Word:  check [2893.78 - 2894.02]
#   Word:  it [2894.02 - 2894.16]
#   Word:  out. [2894.16 - 2894.34]
# Segment [2894.58 - 2901.48]:  That's for graduate students and undergraduate students. And there's a huge, I think $45,000
#   Word:  That's [2894.58 - 2894.78]
#   Word:  for [2894.78 - 2895.02]
#   Word:  graduate [2895.02 - 2895.74]
#   Word:  students [2895.74 - 2896.18]
#   Word:  and [2896.18 - 2896.56]
#   Word:  undergraduate [2896.56 - 2896.96]
#   Word:  students. [2896.96 - 2897.82]
#   Word:  And [2898.34 - 2898.58]
#   Word:  there's [2898.58 - 2898.98]
#   Word:  a [2898.98 - 2899.16]
#   Word:  huge, [2899.16 - 2899.42]
#   Word:  I [2899.98 - 2900.24]
#   Word:  think [2900.24 - 2900.40]
#   Word:  $45 [2900.40 - 2900.80]
#   Word: ,000 [2900.80 - 2901.48]
# Segment [2901.48 - 2908.34]:  in cash prizes, but also a bunch of free training and AI that you'll get along with the effort. So
#   Word:  in [2901.48 - 2901.96]
#   Word:  cash [2901.96 - 2902.20]
#   Word:  prizes, [2902.20 - 2902.70]
#   Word:  but [2902.74 - 2902.94]
#   Word:  also [2902.94 - 2903.22]
#   Word:  a [2903.22 - 2903.44]
#   Word:  bunch [2903.44 - 2903.68]
#   Word:  of [2903.68 - 2903.84]
#   Word:  free [2903.84 - 2904.08]
#   Word:  training [2904.08 - 2904.54]
#   Word:  and [2904.54 - 2904.80]
#   Word:  AI [2904.80 - 2905.06]
#   Word:  that [2905.06 - 2905.46]
#   Word:  you'll [2905.46 - 2905.66]
#   Word:  get [2905.66 - 2905.88]
#   Word:  along [2905.88 - 2906.70]
#   Word:  with [2906.70 - 2907.08]
#   Word:  the [2907.08 - 2907.44]
#   Word:  effort. [2907.44 - 2907.98]
#   Word:  So [2908.10 - 2908.34]
# Segment [2908.34 - 2913.44]:  I really encourage you if you're a student, that's a great thing that's happening this fall that you
#   Word:  I [2908.34 - 2908.56]
#   Word:  really [2908.56 - 2908.98]
#   Word:  encourage [2908.98 - 2909.32]
#   Word:  you [2909.32 - 2909.52]
#   Word:  if [2909.52 - 2909.62]
#   Word:  you're [2909.62 - 2909.76]
#   Word:  a [2909.76 - 2909.86]
#   Word:  student, [2909.86 - 2910.32]
#   Word:  that's [2910.60 - 2911.16]
#   Word:  a [2911.16 - 2911.26]
#   Word:  great [2911.26 - 2911.46]
#   Word:  thing [2911.46 - 2911.74]
#   Word:  that's [2911.74 - 2911.98]
#   Word:  happening [2911.98 - 2912.30]
#   Word:  this [2912.30 - 2912.68]
#   Word:  fall [2912.68 - 2913.00]
#   Word:  that [2913.00 - 2913.26]
#   Word:  you [2913.26 - 2913.44]
# Segment [2913.44 - 2918.58]:  could be a part of. So check it out. If you just search for data for good Purdue, the link will
#   Word:  could [2913.44 - 2913.62]
#   Word:  be [2913.62 - 2913.82]
#   Word:  a [2913.82 - 2913.94]
#   Word:  part [2913.94 - 2914.18]
#   Word:  of. [2914.18 - 2914.40]
#   Word:  So [2914.62 - 2914.70]
#   Word:  check [2914.70 - 2915.28]
#   Word:  it [2915.28 - 2915.44]
#   Word:  out. [2915.44 - 2915.64]
#   Word:  If [2915.76 - 2915.90]
#   Word:  you [2915.90 - 2916.00]
#   Word:  just [2916.00 - 2916.16]
#   Word:  search [2916.16 - 2916.38]
#   Word:  for [2916.38 - 2916.56]
#   Word:  data [2916.56 - 2916.80]
#   Word:  for [2916.80 - 2917.04]
#   Word:  good [2917.04 - 2917.24]
#   Word:  Purdue, [2917.24 - 2917.54]
#   Word:  the [2917.94 - 2918.02]
#   Word:  link [2918.02 - 2918.46]
#   Word:  will [2918.46 - 2918.58]
# Segment [2918.58 - 2925.50]:  be there. And I think you could register, you know, if you hear this right after it airs, go check it
#   Word:  be [2918.58 - 2918.76]
#   Word:  there. [2918.76 - 2919.00]
#   Word:  And [2919.24 - 2919.24]
#   Word:  I [2919.24 - 2919.66]
#   Word:  think [2919.66 - 2919.84]
#   Word:  you [2919.84 - 2920.04]
#   Word:  could [2920.04 - 2920.16]
#   Word:  register, [2920.16 - 2920.60]
#   Word:  you [2921.18 - 2921.30]
#   Word:  know, [2921.30 - 2921.44]
#   Word:  if [2921.58 - 2921.70]
#   Word:  you [2921.70 - 2921.84]
#   Word:  hear [2921.84 - 2922.10]
#   Word:  this [2922.10 - 2922.44]
#   Word:  right [2922.44 - 2923.12]
#   Word:  after [2923.12 - 2923.44]
#   Word:  it [2923.44 - 2923.62]
#   Word:  airs, [2923.62 - 2924.22]
#   Word:  go [2924.24 - 2925.04]
#   Word:  check [2925.04 - 2925.34]
#   Word:  it [2925.34 - 2925.50]
# Segment [2925.50 - 2931.02]:  out and sign up right away. Fantastic. Awesome, Chris. Well, good to talk things through and
#   Word:  out [2925.50 - 2925.72]
#   Word:  and [2925.72 - 2926.00]
#   Word:  sign [2926.00 - 2926.44]
#   Word:  up [2926.44 - 2926.64]
#   Word:  right [2926.64 - 2926.82]
#   Word:  away. [2926.82 - 2927.08]
#   Word:  Fantastic. [2927.48 - 2927.92]
#   Word:  Awesome, [2928.50 - 2928.78]
#   Word:  Chris. [2928.94 - 2929.04]
#   Word:  Well, [2929.34 - 2929.44]
#   Word:  good [2929.52 - 2929.78]
#   Word:  to [2929.78 - 2929.92]
#   Word:  talk [2929.92 - 2930.14]
#   Word:  things [2930.14 - 2930.42]
#   Word:  through [2930.42 - 2930.70]
#   Word:  and [2930.70 - 2931.02]
# Segment [2931.74 - 2938.84]:  enjoy the rest of your week until we hear about 02 or GPT-5. We'll see you next time.
#   Word:  enjoy [2931.74 - 2932.02]
#   Word:  the [2932.02 - 2932.26]
#   Word:  rest [2932.26 - 2932.46]
#   Word:  of [2932.46 - 2932.58]
#   Word:  your [2932.58 - 2932.66]
#   Word:  week [2932.66 - 2932.98]
#   Word:  until [2932.98 - 2933.64]
#   Word:  we [2933.64 - 2933.88]
#   Word:  hear [2933.88 - 2934.12]
#   Word:  about [2934.12 - 2934.44]
#   Word:  02 [2934.44 - 2935.32]
#   Word:  or [2935.32 - 2936.00]
#   Word:  GPT [2936.00 - 2937.04]
#   Word: -5. [2937.04 - 2937.42]
#   Word:  We'll [2937.66 - 2938.06]
#   Word:  see [2938.06 - 2938.24]
#   Word:  you [2938.24 - 2938.36]
#   Word:  next [2938.36 - 2938.56]
#   Word:  time. [2938.56 - 2938.84]
# Segment [2939.00 - 2941.12]:  There's always another one coming. See you next time.
#   Word:  There's [2939.00 - 2939.32]
#   Word:  always [2939.32 - 2939.58]
#   Word:  another [2939.58 - 2939.86]
#   Word:  one [2939.86 - 2940.06]
#   Word:  coming. [2940.06 - 2940.34]
#   Word:  See [2940.56 - 2940.62]
#   Word:  you [2940.62 - 2940.70]
#   Word:  next [2940.70 - 2940.86]
#   Word:  time. [2940.86 - 2941.12]
# Segment [2944.80 - 2952.22]:  Thank you for listening to Practical AI. You know what's cool? Free stickers. During the month of
#   Word:  Thank [2944.80 - 2945.36]
#   Word:  you [2945.36 - 2945.68]
#   Word:  for [2945.68 - 2945.90]
#   Word:  listening [2945.90 - 2946.22]
#   Word:  to [2946.22 - 2946.66]
#   Word:  Practical [2946.66 - 2947.48]
#   Word:  AI. [2947.48 - 2947.76]
#   Word:  You [2948.56 - 2948.70]
#   Word:  know [2948.70 - 2948.80]
#   Word:  what's [2948.80 - 2948.98]
#   Word:  cool? [2948.98 - 2949.20]
#   Word:  Free [2949.66 - 2949.90]
#   Word:  stickers. [2949.90 - 2950.32]
#   Word:  During [2951.02 - 2951.36]
#   Word:  the [2951.36 - 2951.62]
#   Word:  month [2951.62 - 2951.94]
#   Word:  of [2951.94 - 2952.22]
# Segment [2952.22 - 2957.72]:  September, we're mailing out change log sticker packs to everyone who leaves us a thoughtful
#   Word:  September, [2952.22 - 2952.64]
#   Word:  we're [2953.02 - 2953.32]
#   Word:  mailing [2953.32 - 2953.54]
#   Word:  out [2953.54 - 2953.90]
#   Word:  change [2953.90 - 2954.28]
#   Word:  log [2954.28 - 2954.72]
#   Word:  sticker [2954.72 - 2955.10]
#   Word:  packs [2955.10 - 2955.48]
#   Word:  to [2955.48 - 2955.70]
#   Word:  everyone [2955.70 - 2956.10]
#   Word:  who [2956.10 - 2956.54]
#   Word:  leaves [2956.54 - 2956.78]
#   Word:  us [2956.78 - 2957.02]
#   Word:  a [2957.02 - 2957.26]
#   Word:  thoughtful [2957.26 - 2957.72]
# Segment [2957.72 - 2965.12]:  five-star review or blog post about our pods. Simply email proof of your review to stickers
#   Word:  five [2957.72 - 2958.26]
#   Word: -star [2958.26 - 2958.50]
#   Word:  review [2958.50 - 2958.84]
#   Word:  or [2958.84 - 2959.18]
#   Word:  blog [2959.18 - 2959.44]
#   Word:  post [2959.44 - 2959.94]
#   Word:  about [2959.94 - 2960.48]
#   Word:  our [2960.48 - 2960.84]
#   Word:  pods. [2960.84 - 2961.30]
#   Word:  Simply [2961.84 - 2962.36]
#   Word:  email [2962.36 - 2962.78]
#   Word:  proof [2962.78 - 2963.36]
#   Word:  of [2963.36 - 2963.78]
#   Word:  your [2963.78 - 2963.94]
#   Word:  review [2963.94 - 2964.32]
#   Word:  to [2964.32 - 2964.62]
#   Word:  stickers [2964.62 - 2965.12]
# Segment [2965.12 - 2971.36]:  at changelog.com alongside your address and we'll mail out the goods anywhere in the world.
#   Word:  at [2965.12 - 2965.74]
#   Word:  changelog [2965.74 - 2966.24]
#   Word: .com [2966.24 - 2966.78]
#   Word:  alongside [2966.78 - 2967.36]
#   Word:  your [2967.36 - 2967.70]
#   Word:  address [2967.70 - 2968.08]
#   Word:  and [2968.08 - 2968.62]
#   Word:  we'll [2968.62 - 2968.90]
#   Word:  mail [2968.90 - 2969.10]
#   Word:  out [2969.10 - 2969.38]
#   Word:  the [2969.38 - 2969.54]
#   Word:  goods [2969.54 - 2969.84]
#   Word:  anywhere [2969.84 - 2970.78]
#   Word:  in [2970.78 - 2971.00]
#   Word:  the [2971.00 - 2971.06]
#   Word:  world. [2971.06 - 2971.36]
# Segment [2971.76 - 2977.86]:  Once again, that's stickers at change log.com, picks or didn't happen only in the month of
#   Word:  Once [2971.76 - 2971.90]
#   Word:  again, [2971.90 - 2972.24]
#   Word:  that's [2972.40 - 2972.72]
#   Word:  stickers [2972.72 - 2973.24]
#   Word:  at [2973.24 - 2973.52]
#   Word:  change [2973.52 - 2973.74]
#   Word:  log [2973.74 - 2974.02]
#   Word: .com, [2974.02 - 2974.68]
#   Word:  picks [2975.00 - 2975.40]
#   Word:  or [2975.40 - 2975.78]
#   Word:  didn't [2975.78 - 2976.12]
#   Word:  happen [2976.12 - 2976.38]
#   Word:  only [2976.38 - 2976.98]
#   Word:  in [2976.98 - 2977.40]
#   Word:  the [2977.40 - 2977.48]
#   Word:  month [2977.48 - 2977.70]
#   Word:  of [2977.70 - 2977.86]
# Segment [2977.86 - 2984.38]:  September. Let's do this. Thanks again to our partners at fly.io, to our beat freak in residence,
#   Word:  September. [2977.86 - 2978.20]
#   Word:  Let's [2978.68 - 2978.86]
#   Word:  do [2978.86 - 2978.98]
#   Word:  this. [2978.98 - 2979.28]
#   Word:  Thanks [2979.60 - 2980.04]
#   Word:  again [2980.04 - 2980.38]
#   Word:  to [2980.38 - 2980.52]
#   Word:  our [2980.52 - 2980.64]
#   Word:  partners [2980.64 - 2980.96]
#   Word:  at [2980.96 - 2981.44]
#   Word:  fly [2981.44 - 2981.72]
#   Word: .io, [2981.72 - 2982.24]
#   Word:  to [2982.76 - 2982.88]
#   Word:  our [2982.88 - 2983.10]
#   Word:  beat [2983.10 - 2983.34]
#   Word:  freak [2983.34 - 2983.64]
#   Word:  in [2983.64 - 2984.02]
#   Word:  residence, [2984.02 - 2984.38]
# Segment [2984.38 - 2989.42]:  the one and only breakmaster cylinder, and to our longtime sponsors at Sentry.
#   Word:  the [2984.38 - 2985.10]
#   Word:  one [2985.10 - 2985.38]
#   Word:  and [2985.38 - 2985.48]
#   Word:  only [2985.48 - 2985.78]
#   Word:  breakmaster [2985.78 - 2986.36]
#   Word:  cylinder, [2986.36 - 2986.84]
#   Word:  and [2987.16 - 2987.26]
#   Word:  to [2987.26 - 2987.38]
#   Word:  our [2987.38 - 2987.48]
#   Word:  longtime [2987.48 - 2987.80]
#   Word:  sponsors [2987.80 - 2988.46]
#   Word:  at [2988.46 - 2988.84]
#   Word:  Sentry. [2988.84 - 2989.42]
# Segment [2989.92 - 2994.78]:  Use code change log when signing up for a new center team plan and save a hundred bucks.
#   Word:  Use [2989.92 - 2990.20]
#   Word:  code [2990.20 - 2990.46]
#   Word:  change [2990.46 - 2990.74]
#   Word:  log [2990.74 - 2991.16]
#   Word:  when [2991.16 - 2991.62]
#   Word:  signing [2991.62 - 2991.94]
#   Word:  up [2991.94 - 2992.26]
#   Word:  for [2992.26 - 2992.60]
#   Word:  a [2992.60 - 2992.74]
#   Word:  new [2992.74 - 2992.88]
#   Word:  center [2992.88 - 2993.06]
#   Word:  team [2993.06 - 2993.36]
#   Word:  plan [2993.36 - 2993.66]
#   Word:  and [2993.66 - 2994.14]
#   Word:  save [2994.14 - 2994.28]
#   Word:  a [2994.28 - 2994.40]
#   Word:  hundred [2994.40 - 2994.50]
#   Word:  bucks. [2994.50 - 2994.78]
# Segment [2995.48 - 2998.38]:  That's all for now. We'll talk to you again next time.
#   Word:  That's [2995.48 - 2996.00]
#   Word:  all [2996.00 - 2996.12]
#   Word:  for [2996.12 - 2996.26]
#   Word:  now. [2996.26 - 2996.52]
#   Word:  We'll [2997.00 - 2997.18]
#   Word:  talk [2997.18 - 2997.34]
#   Word:  to [2997.34 - 2997.48]
#   Word:  you [2997.48 - 2997.52]
#   Word:  again [2997.52 - 2997.68]
#   Word:  next [2997.68 - 2997.90]
#   Word:  time. [2997.90 - 2998.38]

# %% [markdown]
# ### Align Audio and Transcripts

# %%
import difflib

def find_best_match(parsed_text, whisper_segments):

    best_ratio = 0
    best_segment = None
    for segment in whisper_segments:
        ratio = difflib.SequenceMatcher(None, parsed_text.lower(), segment['text'].lower()).ratio()
        if ratio > best_ratio:
            best_ratio = ratio
            best_segment = segment
    return best_segment

def align_parsed_with_whisper(parsed_segments, whisper_segments):
    aligned = []
    for pseg in parsed_segments:
        best_match = find_best_match(pseg['text'], whisper_segments)
        if best_match:
            aligned.append({
                'speaker': pseg['speaker'],
                'text': pseg['text'],
                'start': best_match['start'],
                'end': best_match['end']
            })
        else:

            aligned.append({
                'speaker': pseg['speaker'],
                'text': pseg['text'],
                'start': None,
                'end': None
            })
    return aligned

parsed_segments = all_transcripts_parsed[first_file.replace(".mp3", ".md")]  
whisper_segments = all_transcriptions[first_file]['segments']

aligned_segments = align_parsed_with_whisper(parsed_segments, whisper_segments)

for seg in aligned_segments[:5]:
    print(f"Speaker: {seg['speaker']}, Start: {seg['start']}, End: {seg['end']}")
    print(f"Text: {seg['text']}\n")
# Out:
# Speaker: Daniel Whitenack, Start: 284.64, End: 291.12
# Text: Welcome to another Fully Connected episode of the Practical AI podcast. This is Daniel Whitenack. I am the CEO and founder at Prediction Guard, and I'm joined by my co-host, Chris Benson, who is a principal AI research engineer at Lockheed Martin. In these Fully Connected episodes we try to keep you fully connected with everything that's happening in the machine learning and data science and AI worlds, and hopefully share some things with you that will help you level up your machine learning and AI game. How are you doing, Chris? It'll be fun to catch up on a few things that have been happening over the past couple weeks today.
#
# Speaker: Chris Benson, Start: 302.18, End: 308.0
# Text: There's so much going on, oh my gosh.
#
# Speaker: Daniel Whitenack, Start: 491.08, End: 492.8
# Text: Always, yes.
#
# Speaker: Chris Benson, Start: 302.18, End: 308.0
# Text: We'll have to pick and choose what we have time to hit here.
#
# Speaker: Daniel Whitenack, Start: 320.4, End: 327.46
# Text: How are you hearing about AI things these days, Chris? Maybe that's a even something that people might be interested in knowing. We've talked about this a few times on the show, but there may be new listeners who kind of got into the show after Gen AI stuff, and they're trying to figure out where to keep up with news, and learn things...

# %% [markdown]
# ### Data Segments to feed the model

# %% [markdown]
# audio_folder_path = "/Users/kiran/Desktop/TDM/Sample Train Set /Audio"
# base_output_dir = "/Users/kiran/Desktop/TDM/Sample Train Set /Chunks"
#
# def build_aligned_segments_dict(all_parsed_transcripts, all_whisper_transcriptions):
#     aligned_segments_dict = {}
#
#     for audio_filename_with_ext, parsed_segments in all_parsed_transcripts.items():
#
#         audio_filename = audio_filename_with_ext.replace(".md", ".mp3")
#         if audio_filename not in all_whisper_transcriptions:
#             print(f"Audio file {audio_filename} not found in transcriptions.")
#             continue
#
#         whisper_segments = all_whisper_transcriptions[audio_filename]['segments']
#
#         aligned_segments = []
#         for pseg in parsed_segments:
#             # Basic string match with best matching whisper segment to assign timestamp
#             best_match = None
#             best_ratio = 0
#             import difflib
#             for wseg in whisper_segments:
#                 ratio = difflib.SequenceMatcher(None, pseg['text'].lower(), wseg['text'].lower()).ratio()
#                 if ratio > best_ratio:
#                     best_ratio = ratio
#                     best_match = wseg
#
#             if best_match:
#                 aligned_segments.append({
#                     "speaker": pseg["speaker"],
#                     "text": pseg["text"],
#                     "start": best_match["start"],
#                     "end": best_match["end"],
#                 })
#             else:
#
#                 aligned_segments.append({
#                     "speaker": pseg["speaker"],
#                     "text": pseg["text"],
#                     "start": None,
#                     "end": None,
#                 })
#         aligned_segments_dict[audio_filename] = aligned_segments
#
#     return aligned_segments_dict
#
#
# aligned_segments_dict = build_aligned_segments_dict(all_transcripts_parsed, all_transcriptions)
#
#
# chunk_multiple_files(audio_folder_path, aligned_segments_dict, base_output_dir)

# %% [markdown]
# import os
# import wave
# import contextlib
# import csv
#
# def get_audio_duration(filepath):
#     with contextlib.closing(wave.open(filepath,'r')) as f:
#         frames = f.getnframes()
#         rate = f.getframerate()
#         duration = frames / float(rate)
#     return duration
#
# def prepare_yourtts_metadata(chunks_base_dir, output_csv_path):
#     rows = []
#     # Walk through all chunk folders and gather wav files and metadata.csv
#     for episode_folder in os.listdir(chunks_base_dir):
#         ep_path = os.path.join(chunks_base_dir, episode_folder)
#         if not os.path.isdir(ep_path):
#             continue
#
#         metadata_file = os.path.join(ep_path, "metadata.csv")
#         if not os.path.exists(metadata_file):
#             print(f"Warning: metadata.csv not found in {ep_path}")
#             continue
#
#         with open(metadata_file, newline='', encoding='utf-8') as csvfile:
#             reader = csv.DictReader(csvfile)
#             for row in reader:
#                 wav_path = row["file"]
#                 transcript = row["text"]
#                 speaker = row["speaker"]
#                 duration = get_audio_duration(wav_path)
#                 # YourTTS metadata format
#                 rows.append(f"{wav_path}|{duration:.2f}|{transcript}|{speaker}")
#
#     # Save combined metadata
#     with open(output_csv_path, "w", encoding='utf-8') as f:
#         for line in rows:
#             f.write(line + "\n")
#     print(f"YourTTS metadata saved to {output_csv_path}")
#
# # Example usage:
# chunks_folder = "/Users/kiran/Desktop/TDM/Sample Train Set /Chunks"
# yourtts_metadata_path = "/Users/kiran/Desktop/TDM/yourtts_metadata.csv"
# prepare_yourtts_metadata(chunks_folder, yourtts_metadata_path)

# %% [markdown]
# git clone https://github.com/freds0/YourTTS.git
# cd YourTTS

# %% [markdown]
# import os
# os.chdir("YourTTS")

# %%
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: 'requirements.txt'
# Obtaining file:///Users/kiran/Desktop/TDM/YourTTS
# ERROR: file:///Users/kiran/Desktop/TDM/YourTTS does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
